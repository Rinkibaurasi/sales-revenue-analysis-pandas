# %% [markdown]
# <a href="https://colab.research.google.com/github/Rinkibaurasi/sales-revenue-analysis-pandas/blob/main/sales_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("sample_101_Sales_Dataset.csv")
print(df)
# Out:
#    Order ID  Amount  Profit  Quantity         Category      Sub-Category  \
# 0   B-26776    9726    1275         5      Electronics  Electronic Games
# 1   B-26776    9726    1275         5      Electronics  Electronic Games
# 2   B-26776    9726    1275         5      Electronics  Electronic Games
# 3   B-26776    4975    1330        14      Electronics          Printers
# 4   B-26776    4975    1330        14      Electronics          Printers
# ..      ...     ...     ...       ...              ...               ...
# 95  B-25142    5105     465         5      Electronics          Printers
# 96  B-25326    5578     277        16        Furniture            Tables
# 97  B-25326    5578     277        16        Furniture            Tables
# 98  B-26795    5224    1958        16        Furniture            Chairs
# 99  B-26795    5002    1801        11  Office Supplies           Markers
#
#     PaymentMode  Order Date     CustomerName     State      City Year-Month
# ...

# %%
df.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-26776    9726    1275         5  Electronics  Electronic Games
# 1  B-26776    9726    1275         5  Electronics  Electronic Games
# 2  B-26776    9726    1275         5  Electronics  Electronic Games
# 3  B-26776    4975    1330        14  Electronics          Printers
# 4  B-26776    4975    1330        14  Electronics          Printers
#
#   PaymentMode  Order Date   CustomerName     State     City Year-Month
# 0         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 1         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
# 2         UPI  2021-07-25   Robert Stone  New York  Buffalo    2021-07
# 3         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 4         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      100 non-null    object
#  1   Amount        100 non-null    int64
#  2   Profit        100 non-null    int64
#  3   Quantity      100 non-null    int64
#  4   Category      100 non-null    object
#  5   Sub-Category  100 non-null    object
#  6   PaymentMode   100 non-null    object
#  7   Order Date    100 non-null    object
#  8   CustomerName  100 non-null    object
#  9   State         100 non-null    object
#  10  City          100 non-null    object
#  11  Year-Month    100 non-null    object
# dtypes: int64(3), object(9)
# memory usage: 9.5+ KB

# %% [markdown]
# Data Cleaning

# %%
df.isnull().sum()
# Out:
# Order ID        0
# Amount          0
# Profit          0
# Quantity        0
# Category        0
# Sub-Category    0
# PaymentMode     0
# Order Date      0
# CustomerName    0
# State           0
# City            0
# Year-Month      0
# dtype: int64

# %%
df.dropna()
# Out:
#    Order ID  Amount  Profit  Quantity         Category      Sub-Category  \
# 0   B-26776    9726    1275         5      Electronics  Electronic Games
# 1   B-26776    9726    1275         5      Electronics  Electronic Games
# 2   B-26776    9726    1275         5      Electronics  Electronic Games
# 3   B-26776    4975    1330        14      Electronics          Printers
# 4   B-26776    4975    1330        14      Electronics          Printers
# ..      ...     ...     ...       ...              ...               ...
# 95  B-25142    5105     465         5      Electronics          Printers
# 96  B-25326    5578     277        16        Furniture            Tables
# 97  B-25326    5578     277        16        Furniture            Tables
# 98  B-26795    5224    1958        16        Furniture            Chairs
# 99  B-26795    5002    1801        11  Office Supplies           Markers
#
#     PaymentMode  Order Date     CustomerName     State      City Year-Month
# ...

# %% [markdown]
# Total Sales, Profit & Quantity

# %%
total_sales = df['Amount'].sum()
total_profit = df['Profit'].sum()
total_quantity = df['Quantity'].sum()

print("total_sales" , total_sales )
print("total_profit" , total_profit)
print( "total_quantity" ,total_quantity)
# Out:
# total_sales 483887
# total_profit 109414
# total_quantity 1025

# %%
category_sales = df.groupby('Category')['Amount'].sum().sort_values(ascending=False)
print(category_sales)
# Out:
# Category
# Office Supplies    175301
# Furniture          166331
# Electronics        142255
# Name: Amount, dtype: int64

# %%
top_products = df.groupby('Sub-Category')['Amount'].sum().sort_values(ascending=False).head(5)
print(top_products)
# Out:
# Sub-Category
# Tables              73274
# Binders             67319
# Pens                61022
# Printers            58762
# Electronic Games    47353
# Name: Amount, dtype: int64

# %%
monthly_sales = df.groupby('Year-Month')['Amount'].sum().head()
print(monthly_sales)
# Out:
# Year-Month
# 2020-03     2975
# 2020-04     6396
# 2020-05    15500
# 2020-10    11156
# 2020-11    19911
# Name: Amount, dtype: int64

# %%
state_profit = df.groupby('State')['Profit'].sum().sort_values(ascending=False)
print(state_profit)
# Out:
# State
# California    32003
# New York      21443
# Florida       20029
# Ohio          16251
# Texas         14374
# Illinois       5314
# Name: Profit, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(7,3))
sns.barplot(x=category_sales.values, y=category_sales.index)
plt.title("Revenue by Category")
plt.xlabel("Revenue")
plt.ylabel("Category")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
monthly_sales.plot(marker='o')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales Amount")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
top_products.plot(kind='bar', figsize=(8,5), title="Top 5 Sub-Categories by Revenue")
plt.show()

# %%
df.to_excel("cleaned_sales_data.xlsx")

# %%
df['PaymentMode'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    title='Payment Mode Distribution',
    figsize=(6,6)
)
plt.ylabel('')
plt.show()
